# %% [markdown]
# Statistics-> deals with collection organization, analysis, Interpetation with the help of statistics we can do best decision making.
# # 📊 Types of Statistics
#
# Statistics is the **foundation of Machine Learning**.
# It helps us understand data and make decisions from it.
#
# There are **two main types** of statistics:
#
# 1. Descriptive Statistics
# 2. Inferential Statistics
#
# ---
#
# # 1️⃣ Descriptive Statistics
#
# 👉 Used to **summarize and describe** the data you already have.
#
# No prediction.
# No future guessing.
#
# It answers:
# **"What does my dataset look like?"**
#
# ---
#
# ## Measures of Central Tendency
# These tell us the "center" of the data.
#
# - **Mean** → Average value
# - **Median** → Middle value after sorting
# - **Mode** → Most frequent value
#
# Example:
# Data = [70, 75, 80, 90, 95]
# Mean = average
#
#
# ---
#
# ## Measures of Spread
# These tell us how spread out the data is.
#
# - **Range** → max - min
# - **Variance** → average squared distance from mean
# - **Standard Deviation** → square root of variance
#
# ---
#
# ## Measures of Position
# These show where values lie.
#
# - Percentiles
# - Quartiles
#
# ---
#
# ## Visualization Tools
# Often used in descriptive statistics:
#
# - Histograms
# - Box plots
# - Bar charts
#
# ---
#
# ## Where this is used in ML
# - Data understanding
# - Data cleaning
# - Exploratory Data Analysis (EDA)
# - Feature engineering
#
# Before building models → we ALWAYS do descriptive analysis.
#
# ---
#
# ---
#
# # 2️⃣ Inferential Statistics
#
# 👉 Used to **make conclusions about a large population using a small sample**.
#
# This is about prediction and decision making.
#
# ---
#
# ## Example
#
# Survey 1,000 people.
# Conclude 60% of the whole city likes online shopping.
#
# You are **inferring** population behavior from a sample.
#
# ---
#
# ## Major Areas Inside Inferential Statistics
#
# - Hypothesis testing
# - Confidence intervals
# - Regression
# - Probability distributions
#
# ---
#
# ## ML Connection 🔥
# Many ML algorithms are built on inferential ideas.
#
# Examples:
# - Linear Regression
# - Logistic Regression
# - A/B Testing
# - Model accuracy estimation
#
# ---
#
# ---
#
# # 🧠 Memory Trick
#
# **Descriptive = Describe what happened**
# **Inferential = Predict beyond the data**
#
# ---
#
# ---
#
# # 🚀 Learning Roadmap for ML
#
# To avoid confusion later, learn in this order:
#
# 1. Descriptive statistics
# 2. Probability
# 3. Random variables
# 4. Distributions
# 5. Sampling
# 6. Inferential statistics
# 7. ML algorithms
#
# ---
#
# population vs sample:
#
# if there are 100k people are in an island then we called it as popolation.
#
# sample is a subpart of population. we just take sample data and prove something in population.
#
# # 📊 Measures of Central Tendency (Population vs Sample)
#
# Measures of central tendency tell us where the **center** of the data lies.
#
# The three main measures are:
# 1. Mean
# 2. Median
# 3. Mode
#
# ---
#
# # 🧠 Population vs Sample (VERY IMPORTANT)
#
# - **Population** → Entire group of data.
# - **Sample** → Small subset taken from the population.
#
# Example:
# Population = marks of all students in a university
# Sample = marks of 100 students
#
# We use slightly different formulas for population and sample.
#
# ---
#
# ---
#
# # 1️⃣ Mean (Average)
#
# The mean is the sum of values divided by the number of values.
#
# ---
#
# ## ✅ Population Mean (μ)
#
# Formula:
#
# μ = (Σ Xi) / N
#
# Where:
# - Σ = sum of
# - Xi = each value
# - N = total population size
#
# ---
#
# ## ✅ Sample Mean (x̄)
#
# Formula:
#
# x̄ = (Σ Xi) / n
#
# Where:
# - n = sample size
#
# ---
#
# ## Example
#
# Data = [10, 20, 30]
#
# Mean = (10 + 20 + 30) / 3 = 20
#
# ---
#
# ---
#
# # 2️⃣ Median
#
# The middle value after sorting the data.
#
# ---
#
# ## Steps
# 1. Sort data
# 2. If odd → middle value
# 3. If even → average of two middle values
#
# ---
#
# ## Example (odd)
# [10, 20, 30] → median = 20
#
# ## Example (even)
# [10, 20, 30, 40]
# median = (20 + 30) / 2 = 25
#
# ---
#
# 👉 Median formula is same for **population & sample**.
#
# ---
#
# ---
#
# # 3️⃣ Mode
#
# The value that appears most frequently.
#
# ---
#
# ## Example
# [10, 20, 20, 30]
#
# Mode = 20
#
# ---
#
# 👉 Same for population & sample.
#
# ---
#
# ---
#
# # 🎯 Important Symbols to Remember
#
# - Population mean → μ
# - Sample mean → x̄
#
# You will see these everywhere in ML & statistics.
#
# ---
#
# ---
#
# # 🚀 ML Insight
#
# Why mean is important?
# - Used in normalization
# - Used in standardization
# - Used in loss calculations
# - Used in probability distributions
#
# Almost every ML pipeline touches mean.
#
# ---
#
# # 📊 Measures of Dispersion
#
# Measures of dispersion tell us **how spread out the data is around the center**.
#
# Two datasets can have the same mean but behave completely differently.
#
# Understanding spread is CRITICAL in:
# - Machine Learning
# - Risk analysis
# - Data consistency
# - Model stability
#
# ---
#
# # 🧠 Why Do We Need Dispersion?
#
# Example:
#
# Class A marks → [50, 50, 50, 50, 50]
# Class B marks → [10, 30, 50, 70, 90]
#
# Both have:
# Mean = 50
#
# But are they similar? ❌
# Class B is much more spread.
#
# 👉 Dispersion helps us see this difference.
#
# ---
#
# ---
#
# # Main Measures of Dispersion
#
# 1. Range
# 2. Variance
# 3. Standard Deviation
# 4. Interquartile Range (IQR)
#
# ---
#
# ---
#
# # 1️⃣ Range
#
# The simplest measure.
#
# Formula:
#
# Range = Maximum value − Minimum value
#
# ---
#
# ## Example
# Data = [10, 20, 30, 40]
#
# Range = 40 − 10 = 30
#
# ---
#
# ## Problem with Range
# It depends only on two values (max & min).
# If there is an outlier → range becomes misleading.
#
# ---
#
# ---
#
# # 2️⃣ Variance (Most Important)
#
# Variance measures the **average squared distance from the mean**.
#
# It tells us how far data points are from the center.
#
# ---
#
# ## ✅ Population Variance (σ²)
#
# Formula:
#
# σ² = Σ (Xi − μ)² / N
#
# Where:
# - μ = population mean
# - N = population size
#
# ---
#
# ## ✅ Sample Variance (s²)
#
# Formula:
#
# s² = Σ (Xi − x̄)² / (n − 1)
#
# Where:
# - x̄ = sample mean
# - n = sample size
#
# ---
#
# ## Why divide by (n − 1)?
# To correct bias when estimating population from sample.
#
# (This is SUPER famous in interviews.)
#
# ---
#
# ---
#
# # 3️⃣ Standard Deviation (VERY VERY IMPORTANT 🔥)
#
# Standard deviation = square root of variance.
#
# Why?
# Because variance is in squared units, which is hard to interpret.
#
# So we bring it back to original scale.
#
# ---
#
# ## ✅ Population Standard Deviation
#
# σ = √σ²
#
# ---
#
# ## ✅ Sample Standard Deviation
#
# s = √s²
#
# ---
#
# ## Meaning
#
# Small SD → data close to mean
# Large SD → data widely spread
#
# ---
#
# ---
#
# # 4️⃣ Interquartile Range (IQR)
#
# Used to measure spread of the **middle 50%** of data.
#
# Formula:
#
# IQR = Q3 − Q1
#
# Where:
# - Q1 = 25th percentile
# - Q3 = 75th percentile
#
# ---
#
# ## Why important?
# Less affected by outliers.
#
# ---
#
# ---
#
# # 🎯 ML & Data Science Connection
#
# Dispersion is used in:
#
# - Feature scaling
# - Standardization (z-score)
# - Detecting outliers
# - Distribution understanding
# - Model confidence
# - Risk measurement
#
# If spread is huge → predictions become unstable.
#
# ---
#
# ---
#
# # 🧠 Memory Trick
#
# Mean → center
# Variance → average distance from center
# Standard deviation → actual usable distance
#
# ---
#
# ---
#
# # 🚀 What Comes After This?
#
# After dispersion, the next big topics are:
#
# 1. Probability
# 2. Random variables
# 3. Distributions (Normal, Binomial, etc.)
# 4. Sampling
# 5. Hypothesis testing
#
# These power almost all ML algorithms.
#
# ---
