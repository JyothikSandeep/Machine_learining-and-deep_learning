# %%
# !pip install pandas

# %%
import pandas as pd

data=[1,2,3,4]

data1=pd.Series(data)

print(data1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data1={"name":"sandy","age":10,"gender":"Male"}

data=pd.Series(data1)
print(data)
# Out:
# name      sandy
# age          10
# gender     Male
# dtype: object

# %%
data={
    "Name":["sandy","candy","randy"],
    "age":[10,20,30],
    "city":["Banglore","new york","florida"]
}

df=pd.DataFrame(data)
print(df)
# Out:
#     Name  age      city
# 0  sandy   10  Banglore
# 1  candy   20  new york
# 2  randy   30   florida

# %%
data=pd.read_csv("students_data.csv")
print(data["name"])
# Out:
# 0     Aarav
# 1      Diya
# 2     Rohan
# 3     Sneha
# 4     Kiran
# 5     Meera
# 6     Arjun
# 7     Pooja
# 8     Rahul
# 9    Ananya
# Name: name, dtype: object

# %%
data.head()
# Out:
#    student_id   name  age gender        course  marks  attendance_percent  \
# 0         101  Aarav   20      M            ML     85                  90
# 1         102   Diya   21      F            DL     92                  95
# 2         103  Rohan   19      M            ML     78                  85
# 3         104  Sneha   22      F  Data Science     88                  92
# 4         105  Kiran   23      M            DL     90                  88
#
#    passed
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True

# %%
df.describe()
# Out:
#         age
# count   3.0
# mean   20.0
# std    10.0
# min    10.0
# 25%    15.0
# 50%    20.0
# 75%    25.0
# max    30.0

# %%
df["double_age"]=df["age"].apply(lambda x:x*2)

print(df)
# Out:
#     Name  age      city  double_age
# 0  sandy   10  Banglore          20
# 1  candy   20  new york          40
# 2  randy   30   florida          60

# %%
def triple(data):
    return data*3
df["triple_age"]=df["age"].apply(triple)

print(df)
# Out:
#     Name  age      city  double_age  triple_age
# 0  sandy   10  Banglore          20          30
# 1  candy   20  new york          40          60
# 2  randy   30   florida          60          90
